# %% [markdown]
# # Maple Mono 使用指南
#
# 当你敲下每一行代码，字体在替你表达气质与专注。Maple Mono 的目的很简单：让阅读与书写变得顺畅、统一、并拥有恰到好处的个性。
#
# ## 安装与环境配置
#
# ### 方式一：桌面系统安装
#
# - **Windows**
#   解压字体文件，全部选中，右键选择“安装”或“为所有用户安装”，然后在编辑器与终端里选择字体名称。
#
# - **macOS**
#   双击 `.ttf` / `.otf`，使用“字体册”安装，然后在 iTerm2、JetBrains、VS Code 中选择对应字体族。
#
# - **Linux**
#   - 用户级：将字体放入 `~/.local/share/fonts` 或 `~/.fonts`，运行 `fc-cache -fv`
#   - 系统级：放入 `/usr/local/share/fonts` 或 `/usr/share/fonts`，刷新缓存
#
#   > 验证：运行 `fc-list | grep -i "maple"` 或在编辑器字体列表中搜索“Maple Mono”。
#
# ### 方式二：源码安装
#
# 下载源码并[安装字体](https://github.com/xinetzone/maple-font)：
#
# ```bash
# git clone --recursive https://github.com/xinetzone/maple-font.git
# cd maple-font
# pip install -ve .
# ```
#
# 导入库后，首次使用会自动构建字体文件（约需要 2-3 分钟）：
#
# ```python
# import maple_font
# # 首次导入时会显示：[maple-font] 首次使用，开始构建 Maple Mono 字体...
# ```

# %% [markdown]
# ## 在 Matplotlib 中设置字体
#
# 使用 `set_font()` 函数可以一键设置 Matplotlib 使用 Maple Mono 字体：

# %%
import matplotlib.pyplot as plt
import maple_font

# 设置使用包含中文字符和 Nerd Font 图标的字体
maple_font.set_font(font_type="NF-CN")

# 现在绘制的图表将使用 Maple Mono 字体显示中文和代码
plt.figure(figsize=(10, 6))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Maple Mono 字体测试")
plt.xlabel("X轴")
plt.ylabel("Y轴")
plt.text(2, 2, "包含代码: $y = x^2$")
plt.show()
# Out:
# [maple-font-builder] 成功注册了 18 个字体文件从目录: /media/pc/data/lxw/ai/tasks/maple-font/src/maple_font/data/fonts
# [maple-font-builder] 成功注册了 4 个字体文件从目录: /media/pc/data/lxw/ai/tasks/maple-font/src/maple_font/data/fonts/NF-CN
# [maple-font-builder] 成功注册了 4 个NF-CN类型字体文件
# [maple-font] 已设置Matplotlib使用 'Maple Mono NF CN' 字体

# %% [markdown]
# 支持的字体类型包括：
# - `"NF-CN"`：包含 Nerd Font 图标和中文字符的字体（推荐）
# - `"NF"`：包含 Nerd Font 图标但无中文字符的字体
# - `"TTF"`：标准 TTF 格式字体
# - `"TTF-AutoHint"`：经过 AutoHint 优化的 TTF 格式字体
# - `"Variable"`：可变字体

# %% [markdown]
# ## Glyph 管理

# %%
import maple_font

# 获取可用的 glyph 列表
glyphs = maple_font.get_available_glyphs(font_type="NF-CN")
print(f"找到 {len(glyphs)} 个可用 glyph")
print(f"前10个 glyph: {glyphs[:10]}")

# 检查特定 glyph 是否存在
glyph_exists = maple_font.check_glyph_exists("glyph_name", font_type="NF-CN")
print(f"Glyph 'glyph_name' 是否存在: {glyph_exists}")
# Out:
# 找到 33579 个可用 glyph
# 前10个 glyph: ['.notdef', '.notdef.1', '.null', 'A', 'A-cy', 'A.bg', 'AE', 'AEacute', 'Aacute', 'Abreve']
# Glyph 'glyph_name' 是否存在: False

# %% [markdown]
# ## 自定义字体构建
#
# 你可以构建包含特定 glyph 的自定义字体：

# %%
import maple_font

# 构建包含自定义 glyph 的字体
success = maple_font.build_with_custom_glyphs(
    glyphs=["glyph1", "glyph2"],  # 替换为你需要的 glyph 名称
    force_rebuild=True,  # 强制重新构建
    verbose=True  # 显示详细信息
)

if success:
    print("自定义字体构建成功")
else:
    print("自定义字体构建失败")
# Out:
# [maple-font-builder] 将包含自定义glyphs: ['glyph1', 'glyph2']
# [maple-font-builder] 正在调用构建脚本: /media/pc/data/lxw/ai/tasks/maple-font/build.py，参数: ['--ttf-only', '--nf', '--cn', '--least-styles', '--feat', 'glyph1,glyph2']
# 🧹 Clean cache...
#
# 🚩 Start building Maple Mono Version 7.700 ...
#
# 👉 Variable version for MapleMono-Italic[wght]-VF.ttf
# Rename glyph names
# Generating feature string with italic=True, cn=False, normal=False, calt=True, variable=False, infinite=True, tag=True
# Skip weight remapping since nothing changed.
# ✅ Verified glyph width in MapleMono-Italic[wght]-VF.ttf
# Fix GASP table
# 👉 Variable version for MapleMono[wght]-VF.ttf
# Rename glyph names
# Generating feature string with italic=False, cn=False, normal=False, calt=True, variable=False, infinite=True, tag=True
# Skip weight remapping since nothing changed.
# ✅ Verified glyph width in MapleMono[wght]-VF.ttf
# Fix GASP table
#
# ✨ Instatiate and optimize fonts...
#
# Check and optimize variable fonts
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/Variable/MapleMono-Italic[wght].ttf
# [ INFO     ] is_italic: True -> OK
# [ INFO     ] is_oblique: False -> OK
# [ INFO     ] italic_angle: -10.0 -> OK
# [ INFO     ] run_rise: (3, 17) -> OK
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0078 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/Variable/MapleMono[wght].ttf
# [ INFO     ] is_italic: False -> OK
# [ INFO     ] is_oblique: False -> OK
# [ INFO     ] italic_angle: 0.0 -> OK
# [ INFO     ] run_rise: (0, 1) -> OK
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0064 seconds
# [ INFO     ] Elapsed time 0.0159 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/Variable/MapleMono-Italic[wght].ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0220 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/Variable/MapleMono[wght].ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0194 seconds
# [ INFO     ] Elapsed time 0.0431 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/Variable/MapleMono-Italic[wght].ttf
# [ SUCCESS  ] File saved to /media/pc/data/lxw/ai/tasks/maple-font/fonts/Variable/MapleMono-Italic[wght].ttf
# [ INFO     ] Processing time: 0.0162 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/Variable/MapleMono[wght].ttf
# [ SUCCESS  ] File saved to /media/pc/data/lxw/ai/tasks/maple-font/fonts/Variable/MapleMono[wght].ttf
# [ INFO     ] Processing time: 0.0124 seconds
# [ INFO     ] Elapsed time 0.0306 seconds
# Instantiate TTF
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/Variable/MapleMono-Italic[wght].ttf
# [ INFO     ] Exporting instance 1 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-ThinItalic.ttf
#
# [ INFO     ] Exporting instance 2 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-ExtraLightItalic.ttf
#
# [ INFO     ] Exporting instance 3 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-LightItalic.ttf
#
# [ INFO     ] Exporting instance 4 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-Italic.ttf
#
# [ INFO     ] Exporting instance 5 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-MediumItalic.ttf
#
# [ INFO     ] Exporting instance 6 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-SemiBoldItalic.ttf
#
# [ INFO     ] Exporting instance 7 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-BoldItalic.ttf
#
# [ INFO     ] Exporting instance 8 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-ExtraBoldItalic.ttf
#
# [ INFO     ] Processing time: 7.5089 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/Variable/MapleMono[wght].ttf
# [ INFO     ] Exporting instance 1 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-Thin.ttf
#
# [ INFO     ] Exporting instance 2 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-ExtraLight.ttf
#
# [ INFO     ] Exporting instance 3 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-Light.ttf
#
# [ INFO     ] Exporting instance 4 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-Regular.ttf
#
# [ INFO     ] Exporting instance 5 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-Medium.ttf
#
# [ INFO     ] Exporting instance 6 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-SemiBold.ttf
#
# [ INFO     ] Exporting instance 7 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-Bold.ttf
#
# [ INFO     ] Exporting instance 8 of 8
# [ SUCCESS  ] Static instance saved to fonts/TTF/MapleMono-ExtraBold.ttf
#
# [ INFO     ] Processing time: 7.2054 seconds
# [ INFO     ] Elapsed time 14.7164 seconds
# 👉 Minimal version for MapleMono-BoldItalic.ttf
# 👉 Minimal version for MapleMono-Italic.ttf
# 👉 Minimal version for MapleMono-Regular.ttf
# 👉 Minimal version for MapleMono-Bold.ttf
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-BoldItalic.ttf
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Italic.ttf
# [ INFO     ] is_italic: True -> OK
# [ INFO     ] is_oblique: False -> OK
# [ INFO     ] italic_angle: -10.0 -> OK
# [ INFO     ] run_rise: (3, 17) -> OK
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0072 seconds
# [ INFO     ] Elapsed time 0.0081 seconds
# [ INFO     ] is_italic: True -> OK
# [ INFO     ] is_oblique: False -> OK
# [ INFO     ] italic_angle: -10.0 -> OK
# [ INFO     ] run_rise: (3, 17) -> OK
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0073 seconds
# [ INFO     ] Elapsed time 0.0082 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Regular.ttf
# [ INFO     ] is_italic: False -> OK
# [ INFO     ] is_oblique: False -> OK
# [ INFO     ] italic_angle: 0.0 -> OK
# [ INFO     ] run_rise: (0, 1) -> OK
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0071 seconds
# [ INFO     ] Elapsed time 0.0080 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Bold.ttf
# [ INFO     ] is_italic: False -> OK
# [ INFO     ] is_oblique: False -> OK
# [ INFO     ] italic_angle: 0.0 -> OK
# [ INFO     ] run_rise: (0, 1) -> OK
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0075 seconds
# [ INFO     ] Elapsed time 0.0085 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Italic.ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0240 seconds
# [ INFO     ] Elapsed time 0.0250 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-BoldItalic.ttf
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Regular.ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0247 seconds
# [ INFO     ] Elapsed time 0.0257 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Bold.ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0229 seconds
# [ INFO     ] Elapsed time 0.0240 seconds
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0238 seconds
# [ INFO     ] Elapsed time 0.0249 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Bold.ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0013 seconds
# [ INFO     ] Elapsed time 0.0022 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Italic.ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0015 seconds
# [ INFO     ] Elapsed time 0.0024 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-BoldItalic.ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0016 seconds
# [ INFO     ] Elapsed time 0.0027 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Regular.ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0019 seconds
# [ INFO     ] Elapsed time 0.0031 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Bold.ttf
# [ INFO     ] Correcting contours...
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Regular.ttf
# [ INFO     ] Correcting contours...
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Italic.ttf
# [ INFO     ] Correcting contours...
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-BoldItalic.ttf
# [ INFO     ] Correcting contours...
# [ INFO     ] 331 glyphs were modified: leftarrowoverrightarrow, tcedilla, ii-cy, onesuperior, equal_greater_greater.liga.ss08, Z.bg.cv10, hyphen_greater.liga, tag_info.liga, less_numbersign_hyphen_hyphen.liga.cv01, chi, dje-cy, Z.cv10, tshe-cy, iogonek, exclam_equal_equal.liga, shade, exclam_asciitilde.liga.ss10, Uhorn, Y.bg, hastroke-cy, bar_hyphen.end.seq, exclam_equal.liga, aogonek.cv02, circleddivisionslash, dentistrybottomverticalright, circlemultiply, greater_hyphen.mid.seq, notelement, arrowdbldown, obarred-cy, P.bg, bracketright, notexistential, Ustraightstroke-cy, Tshe-cy, em-cy, braceleft_braceleft_hyphen_hyphen.liga, iogonekdotless, Ghestroke-cy, greater_equal.sta.seq, Ohorn, bar_equal_greater.liga, leftMultimap, uhorn, existential, C.bg, uniEE0A, liraTurkish, Eth, greater_greater_equal.liga.ss08, a, G.bg, triplearrowleft, lslash, .notdef, numbersign.mid.seq, greater_hyphen.end.seq, equal_less_less.liga.ss08, naira, braceleft_braceleft_exclam_hyphen_hyphen.liga, greater_equal.liga, seven.cv09, less_equal.liga.cv01.cv63, eopen, rightTripleArrow, ohorn, asciitilde_equal.liga.ss09, arrowuprighttip, bar_equal_greater.liga.cv01, Q.bg.cv01, brevecomb_hookabovecomb.case, ampersand_ampersand.liga.cv65, greater_hyphen.sta.seq, dcroat, Eng, N.bg, tag_fixme.liga, y, numbersign_braceleft.liga, less_bar_bar.liga, triaglf, ballotxheavy, tau, tag_todo.liga, R.bg, leftTailArrow, aogonek, T.bg, hyphen_hyphen_braceright_braceright.liga, greater_hyphen_greater.liga.cv01, ustraightstroke-cy, ordfeminine.cv02, Hadescender-cy, kaiSymbol, arrowleftdowntip, uogonek, ampersand_equal.liga.cv01.ss11, greater, notasersetup, kadescender-cy, X, tag_hack.liga, interrobang, Endescender-cy, iogonek.cv03, F.bg, a.cv02, notsubset, f, U.bg, OE, zhedescender-cy, Oogonek, nAryCircledDotOperator, tag_eror.liga, universal, bitcoin, Q.cv01, oslash, A.bg, parenright, parenright.superior, hahook-cy, quotedblleft, zerosuperior, checkbox, upperLeftAndLowerRightBlock, sharp-musical, Z.bg, block_end.bg, Dje-cy, tag_mark.liga, ordfeminine, hadescender-cy, l.cv04, greater_equal.mid.seq, equal_less_equal.liga, Iogonek, greater_hyphen_greater.liga, dentistrytopverticalleft, cent, bar_hyphen_greater.liga, V.bg, section, Ccedilla, eogonek, H.bg, coproductarray, hyphen_asciitilde.liga, braceleft, estimated, KaiSymbol, scedilla, bar_equal.mid.seq, quotesinglbase, unionarray, dollar.cv01, ampersand_ampersand_ampersand.liga.cv65, less_numbersign_hyphen_hyphen.liga, sterling, logicaland, won, tbar, D.bg, iogonekdotless.cv06, containsasmembersmall, rightHookArrow, notequal, alpha, piSymbol, bar_equal.sta.seq, Zhedescender-cy, M.bg, k, bar_hyphen.liga, less_equal.sta.seq, bar_hyphen_greater.liga.cv01, bar_equal.liga.ss11, Uogonek, ccedilla, greater_equal_greater.liga.cv01, thorn, J.bg, slash_equal.liga.ss11, Scedilla, asciitilde_at.liga.cv01, less_equal.end.seq, circle_end.bg, emptyset, ereversed-ipa, checkboxchecked, hyphen_hyphen_greater.liga.cv01, greater_equal_greater.liga, equal_equal_greater.liga.cv01, ghestroke-cy, greater_equal.liga.cv64, Icircle, quotereversed, t, hyphen_less_less.liga.ss08, ampersand_equal.liga.cv65.ss11, lowerRightQuadrantWhiteCircle, f.cv11, Lslash, numbersign.end.seq, iogonekdotless.cv03, bracketright_numbersign.liga, bar_equal.end.seq, numbersign_underscore_underscore.liga, minus.superior, sharp-musical_end.bg, numbersign_underscore_parenleft.liga, franc, S.bg, L.bg, exclamdown, hyphen_less.liga.ss08, propersuperset, Chedescender-cy, hyphen, AE, iogonek.cv06, r.cv08, four-gujarati, g.cv05, Oslash, braceright, nArySquareIntersectionOperator, x, ereversed-cy, Eogonek, Ereversed-cy, numbersign_left.decorator, Euro, ampersand.cv01, zero, less_equal.sta.seq.cv01, bar_hyphen.sta.seq, downFrombarArrow, circleddotoperator, tag_note.liga, Q.bg, onequarter, threequarters, rightTabArrow, numbersign_parenleft.liga, less_bar_bar_bar.liga, tag_warn.liga, less_less_hyphen.liga.ss08, equal_equal_greater.liga, e-cy, W.bg, idotless, greaterequal, arrowdown, hyph ...
# [ SUCCESS  ] File saved to /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Bold.ttf
# [ INFO     ] Processing time: 0.6575 seconds
# [ INFO     ] Elapsed time 0.6586 seconds
# [ INFO     ] 329 glyphs were modified: K, A.bg, arrowleftuptip, braceleft, iogonekdotless.cv03, hyphen, Ereversed-cy, y, less_bar_bar_bar.liga, four-gujarati, liraTurkish, lozenge, arrowleftdowntip, franc, U.bg, Scedilla, eng, equal_less_equal.liga, bar_hyphen_greater.liga, tbar, partialdiff, hyphen_greater.liga, less_bar.liga, tag_mark.liga, mu, bar_bar_equal.liga.ss11, sharp-musical_end.bg, leftHalfBlackSquare, leftTailArrow, tag_info.liga, arrowdbldown, aogonek, ampersand_equal.liga.cv01.ss11, L.bg, S.bg, tag_debug.liga, naira, xcircle, quotedblleft, equal_equal_greater.liga.cv01, tag_fatal.liga, seven.cv09, less_equal.liga.cv01.cv63, V.bg, Chedescender-cy, K.bg, slash_equal.liga.ss11, B.bg, zero, zhedescender-cy, I.bg, Eng, parenright.superior, emptyset, hyphen_less_less.liga.ss08, rightarrowoverleftarrow, numbersign.mid.seq, Q.bg, greater, less_hyphen.end.seq, equal_greater_greater.liga.ss08, Q.bg.cv01, numbersign_underscore_underscore.liga, Tcedilla, braceleft_braceleft_exclam_hyphen_hyphen.liga, greater_equal_greater.liga.cv01, hyphen_asciitilde.liga, x, leftTwoheadedArrow, J.bg.cv07, less_numbersign_hyphen_hyphen.liga.cv01, ampersand_ampersand_equal.liga.cv65.ss11, Oogonek, less_equal.end.seq, Lslash, parenright, Kadescender-cy, arrowrightdowntip, less_bar_bar.liga, onequarter, aogonek.cv02, Y.bg, lambdastroke, e-cy, hyphen_hyphen_greater.liga, notequal, Euro, tcedilla, alpha, literSign, estimated, tag_warn.liga, Hadescender-cy, minus.superior, nArySquareIntersectionOperator, Iu-cy, leftMultimap, bar_equal_greater.liga, cent, W.bg, universal, perthousand, piSymbol, greater_equal.sta.seq, Z.bg, uogonek, rightTabArrow, f, OE, T.bg, suchthat, g.cv05, chedescender-cy, tag_hack.liga, arrowdown, iogonek, asciitilde.end.seq, greater_hyphen_greater.liga.cv01, Q.cv01, ereversed-ipa, endescender-cy, checkboxchecked, Dje-cy, numbersign_left.decorator, numbersign.sta.seq, ghestroke-cy, a.cv02, .notdef, ohorn, braceleft_braceleft_hyphen_hyphen.liga, equal_equal_greater.liga, hadescender-cy, ordfeminine, notelement, Uogonek, notsubset, obarred-cy, rupeeIndian, exclamdown, t, uniEE08, em-cy, interrobang, arrowdblleft, Tbar, dentistrybottomverticalright, R.bg, triplearrowleft, D.bg, equal_less_less.liga.ss08, kadescender-cy, bar_equal_greater.liga.cv01, exclam_equal.liga, iogonekdotless, Ohorn, greater_equal.liga.cv64, k, asciitilde_at.liga.cv01, hahook-cy, greater_hyphen.end.seq, Ustraightstroke-cy, circleddotoperator, hyphen_greater.liga.cv01, kaiSymbol, ampersand.cv01, coproductarray, notasersetup, greater_hyphen_greater.liga, iogonekdotless.cv06, ampersand_ampersand_ampersand.liga.cv65, won, greater_equal.liga, C.bg, dcroat, containsasmembersmall, tag_note.liga, bar_hyphen_greater.liga.cv01, numbersign_parenleft.liga, nAryCircledDotOperator, P.bg, onehalf, a, circle_end.bg, idotless, Eth, shade, propersuperset, KaiSymbol, lslash, Ghestroke-cy, Hbar, less_hyphen.mid.seq, dentistrytopverticalleft, Z.cv10, X, N.bg, leftWhitePointer, pagedown, numbersign, greater_hyphen.end.seq.cv01, equal_slash_equal.liga, numbersign_braceleft.liga, dollar.cv01, existential, less_hyphen.sta.seq.cv01, asciitilde_equal.liga.ss09, numbersign_bracketleft.liga, greater_hyphen.mid.seq, downFrombarArrow, less_equal.sta.seq, H.bg, z.cv10, eogonek, chi, less_equal.mid.seq, Obarred-cy, E-cy, quoteleft, G.bg, iogonek.cv03, f.cv11, upperLeftAndLowerRightBlock, unionarray, less_numbersign_hyphen_hyphen.liga, uniEE0A, dje-cy, Iogonek, leftarrowoverrightarrow, greater_greater_equal.liga.ss08, bar_hyphen.liga, bitcoin, quotereversed, Zhedescender-cy, tag_trace.liga, verticalBisectingLineWhiteSquare, tag_eror.liga, Tshe-cy, tshe-cy, oogonek, notexistential, iu-cy, bar_equal.sta.seq, Icircle, equal_greater_equal.liga, quotesinglbase, uhorn, braceright, F.bg, Eogonek, AE, exclam_asciitilde.liga.ss10, bar_equal.end.seq, ustraightstroke-cy, Uhorn, less_equal.liga.cv63, O.bg, bar_hyphen.end.seq, ballotxheavy, tag_todo.liga, rightTripleArrow, lslash.cv04, ordfeminine.cv02, ...
# [ INFO     ] 366 glyphs were modified: Endescender-cy, numbersign_underscore_parenleft.liga, circle_end.bg, notexistential, obarred-cy, bar_equal.end.seq, a, y.cv37, existential, braceleft_braceleft_exclam_hyphen_hyphen.liga, onesuperior, lambdastroke, K.bg, R.bg, ghestroke-cy, Ccedilla, bar_hyphen.sta.seq, circleddotoperator, tcedilla, tag_error.liga, tag_trace.liga, k.cv34, tag_todo.liga, kaiSymbol, exclamdown, Z.bg, ustraightstroke-cy, tag_fixme.liga, iogonek.cv39, lowerRightQuadrantWhiteCircle, C_l.liga, gacute.cv38, G.bg, Z.cv43, block_end.bg, bar_equal_greater.liga, exclam_equal_equal.liga, greater_hyphen.sta.seq, equal_greater_equal.liga, checkboxchecked, less_numbersign_hyphen_hyphen.liga, rightWaveArrow, triplearrowleft, eopen, threequarters, A.bg, W.bg, one, f_f.liga.cv32, greaterequal, t, pagedown, lslash, equal_slash_equal.liga, logicaland, idotless.cv33, iogonekdotless.cv33, a_l.liga, tag_eror.liga, X, gcommaaccent.cv38, braceleft, asciitilde_at.liga.cv01, uniEE0A, lslash.cv04, e, questiondown, numbersign, propersuperset, oogonek, numbersign_parenleft.liga, e_l.liga, onequarter, arrowdown, P.bg, arrowleft, dje-cy, alpha, arrowleftfrombar, greater_hyphen.end.seq.cv01, containsasmembersmall, em-cy, less_equal.liga.cv63, bracketright_numbersign.liga, K, nAryCircledDotOperator, quoteleft, N.bg, oslash, Z.bg.cv43, Iu-cy, greater_equal.liga, Eogonek, gcircumflex.cv38, iogonekdotless, coproductarray, E.bg, universal, Ustraightstroke-cy, asciitilde_greater.liga, a_l_l.liga, endescender-cy, zero, U.bg, f_f.liga, KaiSymbol, hahook-cy.cv36, greater_hyphen_greater.liga.cv01, hookabovecomb.case, less_equal.end.seq, equal_less_equal.liga, less_bar_bar.liga, tbar, suchthat, interrobang, dollar.cv01, rightarrowoverleftarrow, partialdiff, liraTurkish, greater_equal.sta.seq, gcaron.cv38, greater_greater_equal.liga.ss08, i_l_l.liga, numbersign.end.seq, H.bg, ereversed-ipa, leftWhitePointer, onehalf, hyphen_greater_greater.liga.ss08, iogonek, aogonek, Uhorn, rightBlackSmallTriangle, tau, bar_hyphen_greater.liga, less_bar.liga, hookabovecomb, franc, notsubset, uhorn, Q.bg, J.bg, quotereversed, less_equal.sta.seq.cv01, chedescender-cy, iogonekdotless.cv39, uniEE08, cent, leftHookArrow, less_numbersign_hyphen_hyphen.liga.cv01, estimated, ydotbelow, V.bg, Eth, tag_fatal.liga, greater, tag_mark.liga, ampersand_equal.liga.cv01.ss11, Y.bg, C.bg, numbersign_bracketleft.liga, bar_hyphen.end.seq, numbersign.sta.seq, notelement, Eng, piSymbol, circleplus, F.bg, mu, ampersand.cv01, sevensuperior.cv42, chi, rightHookArrow, Aogonek, less_less_hyphen.liga.ss08, four-gujarati, eng, unionarray, greater_equal.end.seq.cv01, union, braceleft_braceleft_hyphen_hyphen.liga, downFrombarArrow, notequal, scedilla, zhedescender-cy, arrowdblleft, leftHalfBlackSquare, verticalBisectingLineWhiteSquare, less_hyphen.sta.seq.cv01, equal_greater_greater.liga.ss08, Q.bg.cv01, greater_hyphen_greater.liga, hadescender-cy, OE, greater_hyphen.end.seq, L.bg, c_l.liga, notasersetup, greater_equal_greater.liga.cv01, checkbox, J.bg.cv40, slash_equal.liga.ss11, Ghestroke-cy, leftTwoheadedArrow, bar_equal.liga.ss11, bar_hyphen_greater.liga.cv01, bar_hyphen.liga, Chedescender-cy, hahook-cy, Ohorn, X.bg, dcroat, exclam_asciitilde.liga.ss10, numbersign_underscore_underscore.liga, dentistrytopverticalleft, hyphen_hyphen_braceright_braceright.liga, tag_warning.liga, l, bar_hyphen.mid.seq, tag_info.liga, I.bg, leftarrowoverrightarrow, ohorn, checkboxx, brevecomb_hookabovecomb.case, circleddivisionslash, Icircle, equal_equal_greater.liga.cv01, Q.cv01, shade, i_l.liga, parenleft.superior, Euro, l.cv04, sharp-musical, Obarred-cy, hyphen_greater.liga, uogonek, numbersign_left.decorator, tshe-cy, Zhedescender-cy, quotedblleft, ordfeminine.cv31, f, greater_hyphen.mid.seq, ereversed-cy, ampersand_ampersand_equal.liga.cv65.ss11, Scedilla, notcontains, ordfeminine, .notdef, ccedilla, x, numbersign_braceleft.liga, seven.cv42, asciitilde_equal.liga.ss09, f.cv44, gdotaccent.cv38, Tbar, Iogonek,  ...
# [ INFO     ] 358 glyphs were modified: braceleft_braceleft_exclam_hyphen_hyphen.liga, arrowleft, four-gujarati, uogonek, nAryCircledDotOperator, T.bg, scedilla, dentistrytopverticalleft, iogonekdotless, greater_hyphen_greater.liga.cv01, bar_hyphen_greater.liga, A.bg, K.bg, numbersign_underscore_parenleft.liga, quotereversed, F.bg, naira, E.bg, obarred-cy, notelement, Hbar, Ccedilla, tau, ereversed-ipa, leftHookArrow, lozenge, mu, numbersign.mid.seq, greater_hyphen_greater.liga, ampersand.cv01, tag_note.liga, gcircumflex.cv38, hookabovecomb, greater_equal.mid.seq, Tbar, gbreve.cv38, n.superior, tag_todo.liga, tag_error.liga, bar_hyphen.end.seq, bar_bar_equal.liga.ss11, greater, Y.bg, l_l.liga, rupeeIndian, less_hyphen.mid.seq, won, I.bg, dentistrybottomverticalright, U.bg, seven.cv42, equal_greater_greater.liga.ss08, AE, a, hyphen_asciitilde.liga, shade, gacute.cv38, braceright, M.bg, gcommaaccent.cv38, i_l_l.liga, z.cv43, bar_equal_greater.liga.cv01, bar_equal.liga.ss11, iogonek.cv39, less_equal.end.seq, x, tag_trace.liga, greater_hyphen.end.seq.cv01, xcircle, t_l.liga, hookabovecomb.case, f_f.liga, perthousand, oslash, ereversed-cy, Chedescender-cy, notcontains, ordfeminine.cv31, less_bar_bar_bar.liga, Kadescender-cy, Oslash, Hadescender-cy, Tcedilla, asciitilde.end.seq, piSymbol, alpha, onehalf, Z.bg.cv43, bar_equal.sta.seq, bar_equal.end.seq, hadescender-cy.cv36, less_equal.liga.cv63, rightTripleArrow, Ustraightstroke-cy, e-cy, dcroat, tag_warn.liga, hyphen_hyphen_greater.liga, u_l_l.liga, S.bg, Tshe-cy, dollar.cv01, union, zero, greater_equal.end.seq.cv01, O.bg, estimated, greater_hyphen.mid.seq, tag_debug.liga, interrobang, logicaland, greater_equal.liga.cv64, Zhedescender-cy, notequal, bar_hyphen.liga, bar_equal.mid.seq, less_equal.mid.seq, notexistential, tag_fatal.liga, circle_end.bg, partialdiff, kaiSymbol, notsubset, containsasmembersmall, iu-cy, e_l_l.liga, slash_equal.liga.ss11, numbersign_parenleft.liga, iogonekdotless.cv33, tshe-cy, cent, less_equal.sta.seq, Q.cv01, literSign, brevecomb_hookabovecomb.case, Q.bg.cv01, greater_equal_greater.liga, t, leftTwoheadedArrow, coproductarray, hyphen_greater.liga.cv01, greater_equal_greater.liga.cv01, arrowleftfrombar, uniEE0A, Ii-cy, a_l.liga, Z.cv43, i_l.liga, exclam_asciitilde.liga.ss10, numbersign_underscore_underscore.liga, bar_equal_greater.liga, sharp-musical, iogonekdotless.cv39, less_numbersign_hyphen_hyphen.liga, numbersign.sta.seq, Z.bg, dje-cy, lowerRightQuadrantWhiteCircle, Dje-cy, downBlackSmallTriangle, less_equal.sta.seq.cv01, ohorn, hastroke-cy, f, lslash.cv04, eogonek, numbersign_bracketleft.liga, hadescender-cy, ampersand_equal.liga.cv65.ss11, exclam_equal.liga, aogonek, a_l_l.liga, less_bar.liga, lambdastroke, propersuperset, bar_hyphen.mid.seq, kadescender-cy, C.bg, greater_equal.sta.seq, Aogonek, bar_hyphen.sta.seq, arrowdown, equal_equal_greater.liga, P.bg, verticalBisectingLineWhiteSquare, KaiSymbol, bitcoin, liraTurkish, pagedown, g.cv38, numbersign_left.decorator, triplearrowleft, parenright, quotesinglbase, ampersand_equal.liga.cv01.ss11, gdotaccent.cv38, uniEE08, G.bg, aogonek.cv31, .notdef, l, equal_slash_equal.liga, triaglf, hahook-cy.cv36, less_hyphen.sta.seq.cv01, ordfeminine, Eth, circlemultiply, tag_fixme.liga, asciitilde_at.liga.cv01, endescender-cy, leftWhitePointer, J.bg, braceleft_braceleft_hyphen_hyphen.liga, c_l.liga, Uhorn, numbersign_braceleft.liga, arrowdblleft, l.cv04, checkbox, quoteleft, tcedilla, leftHalfBlackSquare, circleddivisionslash, uhorn, rightHookArrow, R.bg, u_l.liga, hastroke-cy.cv36, greater_equal.liga, B.bg, zerosuperior, J.bg.cv40, less_numbersign_hyphen_hyphen.liga.cv01, iogonek, greater_hyphen.end.seq, nArySquareIntersectionOperator, equal_equal_greater.liga.cv01, less_less_hyphen.liga.ss08, emptyset, Icircle, bracketright, y.cv37, ustraightstroke-cy, t_t.liga, suchthat, one, r.cv41, existential, Euro, exclam_equal_equal.liga, circleplus, ballotxheavy, numbersign_underscore.liga, eopen, tag_hack.liga, iogonek.cv3 ...
# [ SUCCESS  ] File saved to /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Regular.ttf
# [ INFO     ] Processing time: 0.6392 seconds
# [ INFO     ] Elapsed time 0.6402 seconds
# [ SUCCESS  ] File saved to /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-BoldItalic.ttf
# [ INFO     ] Processing time: 0.7181 seconds
# [ INFO     ] Elapsed time 0.7191 seconds
# [ SUCCESS  ] File saved to /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Italic.ttf
# [ INFO     ] Processing time: 0.7289 seconds
# [ INFO     ] Elapsed time 0.7300 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Bold.ttf
# [ SUCCESS  ] File saved to /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Bold.ttf
# [ INFO     ] Processing time: 0.2116 seconds
# [ INFO     ] Elapsed time 0.2125 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Regular.ttf
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Italic.ttf
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-BoldItalic.ttf
# [ SUCCESS  ] File saved to /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Regular.ttf
# [ INFO     ] Processing time: 0.2333 seconds
# [ INFO     ] Elapsed time 0.2342 seconds
# [ SUCCESS  ] File saved to /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Italic.ttf
# [ INFO     ] Processing time: 0.2575 seconds
# [ INFO     ] Elapsed time 0.2591 seconds
# [ SUCCESS  ] File saved to /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-BoldItalic.ttf
# [ INFO     ] Processing time: 0.2607 seconds
# [ INFO     ] Elapsed time 0.2617 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Bold.ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0955 seconds
# [ INFO     ] Elapsed time 0.0971 seconds
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Regular.ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0853 seconds
# [ INFO     ] Elapsed time 0.0862 seconds
# Generating feature string with italic=False, cn=False, normal=False, calt=True, variable=False, infinite=True, tag=True
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-Italic.ttf
# [ INFO     ] Processing file /media/pc/data/lxw/ai/tasks/maple-font/fonts/TTF/MapleMono-BoldItalic.ttf
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.1008 seconds
# [ INFO     ] Elapsed time 0.1024 seconds
# [ SKIP     ] No changes made
# [ INFO     ] Processing time: 0.0966 seconds
# [ INFO     ] Elapsed time 0.0978 seconds
# Generating feature string with italic=False, cn=False, normal=False, calt=True, variable=False, infinite=True, tag=True
#
#
# Generating feature string with italic=True, cn=False, normal=False, calt=True, variable=False, infinite=True, tag=True
# Generating feature string with italic=True, cn=False, normal=False, calt=True, variable=False, infinite=True, tag=True
# ✅ Verified glyph width in MapleMono-Bold
# ✅ Verified glyph width in MapleMono-Regular
# ✅ Verified glyph width in MapleMono-Italic
# ✅ Verified glyph width in MapleMono-BoldItalic
# 👉 Auto hint MapleMono-Bold.ttf
# 👉 Auto hint MapleMono-Regular.ttf
# 👉 Auto hint MapleMono-Italic.ttf👉 Auto hint MapleMono-BoldItalic.ttf
#
# Generating feature string with italic=False, cn=False, normal=False, calt=True, variable=False, infinite=False, tag=TrueGenerating feature string with italic=False, cn=False, normal=False, calt=True, variable=False, infinite=False, tag=True
#
# Generating feature string with italic=True, cn=False, normal=False, calt=True, variable=False, infinite=False, tag=True
# Generating feature string with italic=True, cn=False, normal=False, calt=True, variable=False, infinite=False, tag=True
#
# 🔧 Patch Nerd-Font v3.4.0 using prebuild base font...
#
# 👉 NerdFont version for MapleMono-Italic.ttf
# 👉 NerdFont version for MapleMono-Bold.ttf
# 👉 NerdFont version for MapleMono-Regular.ttf
# 👉 NerdFont version for MapleMono-BoldItalic.ttf
# ✅ Verified glyph width in MapleMono-NF-Bold
# ✅ Verified glyph width in MapleMono-NF-Italic
# ✅ Verified glyph width in MapleMono-NF-Regular
# ✅ Verified glyph width in MapleMono-NF-BoldItalic
#
# Checking CN static font directory source/cn/static
# ✅ Hash verified
#
# 🔎 Build CN fonts with Nerd-Font...
#
# 👉 NF-CN version for MapleMono-NF-Bold.ttf
# 👉 NF-CN version for MapleMono-NF-Italic.ttf
# 👉 NF-CN version for MapleMono-NF-Regular.ttf
# 👉 NF-CN version for MapleMono-NF-BoldItalic.ttf
# Dropped cmap subtable from font '0':	format  6, platformID  1, platEncID  0
# Dropped cmap subtable from font '1':	format  6, platformID  1, platEncID  0
# Dropped cmap subtable from font '0':	format  6, platformID  1, platEncID  0
# Dropped cmap subtable from font '1':	format  6, platformID  1, platEncID  0
# Dropped cmap subtable from font '0':	format  6, platformID  1, platEncID  0
# Dropped cmap subtable from font '1':	format  6, platformID  1, platEncID  0
# Dropped cmap subtable from font '0':	format  6, platformID  1, platEncID  0
# Dropped cmap subtable from font '1':	format  6, platformID  1, platEncID  0
# Generating feature string with italic=True, cn=True, normal=False, calt=True, variable=False, infinite=True, tag=True
# Generating feature string with italic=False, cn=True, normal=False, calt=True, variable=False, infinite=True, tag=True
# Generating feature string with italic=True, cn=True, normal=False, calt=True, variable=False, infinite=True, tag=True
# Generating feature string with italic=False, cn=True, normal=False, calt=True, variable=False, infinite=True, tag=True
# ✅ Verified glyph width in MapleMono-NF-CN-Bold
# ✅ Verified glyph width in MapleMono-NF-CN-Regular
# ✅ Verified glyph width in MapleMono-NF-CN-Italic
# ✅ Verified glyph width in MapleMono-NF-CN-BoldItalic
#
# 🏁 Build finished at 20:00:07, cost 63.50 s, family name is Maple Mono, +calt;
#    See your fonts in /media/pc/data/lxw/ai/tasks/maple-font/fonts
# [maple-font-builder] 正在清理目标目录: /media/pc/data/lxw/ai/tasks/maple-font/src/maple_font/data/fonts
# [maple-font-builder] 正在将字体文件从 /media/pc/data/lxw/ai/tasks/maple-font/fonts 复制到 /media/pc/data/lxw/ai/tasks/maple-font/src/maple_font/data/fonts
# [maple-font-builder] 已复制: Variable
# [maple-font-builder] 已复制: TTF
# [maple-font-builder] 已复制: TTF-AutoHint
# [maple-font-builder] 已复制: NF
# [maple-font-builder] 已复制: NF-CN
# [maple-font-builder] 已复制: build-config.json
# [maple-font-builder] 字体文件复制成功，共复制 6 个文件，失败 0 个
# 自定义字体构建成功

# %% [markdown]
# ## VSCode
# **VS Code (`settings.json`)**
# ```json
# {
#   // "editor.fontFamily": "'Maple Mono','Maple Mono NF','Maple Mono CN',monospace", 或者
#   "editor.fontFamily": "Maple Mono NF CN, Menlo, Consolas, Maple UI, PingFang, 'Microsoft YaHei', monospace",
#   // "editor.fontLigatures": true, 或者
#   "editor.fontLigatures": "'calt', 'cv01', 'ss01', 'zero'",
#   "editor.lineHeight": 1.6,
#   "terminal.integrated.fontFamily": "Maple Mono NF",
#   "editor.fontSize": 14
# }
# ```
# 也可以考虑直接使用 [Maple Mono 插件](https://marketplace.visualstudio.com/items?itemName=subframe7536.custom-ui-style)

# %% [markdown]
# ## Web 集成
#
# ### 基本引入
#
# ```css
# @font-face {
#   font-family: 'MapleMono';
#   src: url('/fonts/MapleMono-Regular.woff2') format('woff2'),
#        url('/fonts/MapleMono-Regular.ttf') format('truetype');
#   font-weight: 400;
#   font-style: normal;
#   font-display: swap;
# }
# code, pre, kbd, samp {
#   font-family: 'MapleMono', 'Maple Mono', ui-monospace, SFMono-Regular, Menlo, Consolas, monospace;
# }
# ```
#
# ### 可变字体与特性
#
# ```css
# code {
#   font-variation-settings: 'wght' 450, 'slnt' 0;
#   font-feature-settings: "calt" 1, "liga" 1, "ss06" 1, "ss07" 1, "zero" 1;
# }
# ```
#
# ## 特性与进阶
#
# ### 连字与样式控制
#
# - 开启连字（编辑器/浏览器）：
#   - VS Code: `"editor.fontLigatures": true`
#   - CSS: `font-feature-settings: "liga" 1, "calt" 1;`
#
# - 关闭连字：
#   - VS Code: `"editor.fontLigatures": false`
#   - CSS: `font-feature-settings: "liga" 0, "calt" 0;`
#
# - 常见可读性增强：
#   - `"zero" 1`：零与欧（`0`/`O`）区分
#   - `"ss0x"` / `"cv0x"`：按样式集或自定义变体切换字形
#
# ### 中文与混排建议
#
# - 英中文对齐：以等宽代码环境为主，正文避免强制等宽
# - 行高建议：代码块 `line-height` 1.6–1.8
# - 标点与表格：必要时关闭连字或调整字距
# - “CN” 变体：减少 fallback 抖动
#
# ### Maple Mono 与 Sphinx 集成
#
# ```css
# :root {
#   --code-font-stack: 'Maple Mono','Maple Mono CN','Maple Mono NF',ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;
# }
# code, pre, .highlight code, .highlight pre {
#   font-family: var(--code-font-stack);
#   font-feature-settings: "calt" 1, "liga" 1, "zero" 1;
#   line-height: 1.7;
# }
# ```
