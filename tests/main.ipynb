# %% [markdown]
# # 测试

# %%
# %cd ..
# Out:
# /media/pc/data/lxw/ai/tao

# %%
import importlib.util

# 加载 my_script.py 文件
spec = importlib.util.spec_from_file_location(".", "doc/conf.py")
my_module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(my_module)

# # 获取 my_module 的命名空间
# namespace = my_module.__dict__

# # 打印命名空间中的所有变量
# for key, value in namespace.items():
#     print(f"{key}: {value}")

# %%
import importlib
mod = importlib.import_module("conf", "doc")

# %%
import toml

# %%
toml.dumps({
    "nb_mime_priority_overrides":  [
    ('html', 'text/plain', 0),  # 最高级别
    ('latex', 'image/jpeg', None),  # 禁用
    # ('*', 'customtype', 20)
]
})
# Out:
# 'nb_mime_priority_overrides = [ [ "html", "text/plain", 0,], [ "latex", "image/jpeg", "None",],]\n'

# %%
 =
# Out:
# {'__name__': 'conf',
#  '__doc__': 'Sphinx 文档生成器的配置文件。\n\n该文件仅包含最常用选项的配置。完整的选项列表请参阅文档：\nhttps://www.sphinx-doc.org/en/master/usage/configuration.html\n',
#  '__package__': '',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7f46ba8e1b80>,
#  '__spec__': ModuleSpec(name='conf', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f46ba8e1b80>, origin='/media/pc/data/lxw/ai/tao/doc/conf.py'),
#  '__file__': '/media/pc/data/lxw/ai/tao/doc/conf.py',
#  '__cached__': '/media/pc/data/lxw/ai/tao/doc/__pycache__/conf.cpython-312.pyc',
#  '__builtins__': {'__name__': 'builtins',
# ...
